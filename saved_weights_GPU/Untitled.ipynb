# %%
from keras.models import load_model

# %%
cnn_lstm = load_model('CNN_LSTM_bigger_more_data.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-885855df552a> in <module>
# ----> 1 cnn_lstm = load_model('CNN_LSTM_bigger_more_data.h5')
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/saving.py in load_wrapper(*args, **kwargs)
#     490                 os.remove(tmp_filepath)
#     491             return res
# --> 492         return load_function(*args, **kwargs)
#     493
#     494     return load_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/saving.py in load_model(filepath, custom_objects, compile)
#     582     if H5Dict.is_supported_type(filepath):
#     583         with H5Dict(filepath, mode='r') as h5dict:
# --> 584             model = _deserialize_model(h5dict, custom_objects, compile)
#     585     elif hasattr(filepath, 'write') and callable(filepath.write):
#     586         def load_function(h5file):
#
# ...
